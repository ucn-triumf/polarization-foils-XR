# %%
cd /Users/akatsukahiroaki/git/polarization-foils-XR/20220926_XRR/20220926_ana
# Out:
# /Users/akatsukahiroaki/git/polarization-foils-XR/20220926_XRR/20220926_ana

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
path = os.getcwd()
print(path)
# Out:
# /Users/akatsukahiroaki/git/polarization-foils-XR/20220926_XRR/20220926_ana

# %%
data01_axis1,data01_value1 = np.loadtxt("../20220913/A2a.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis2,data01_value2 = np.loadtxt("../20220926/A9_2deg_min.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis3,data01_value3 = np.loadtxt("../20220926/B3_02deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis4,data01_value4 = np.loadtxt("../20220926/B4_02deg_min.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis5,data01_value5 = np.loadtxt("../20220926/C1_2deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis6,data01_value6 = np.loadtxt("../20220926/C2_02deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis7,data01_value7 = np.loadtxt("../20220926/C4_1deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis8,data01_value8 = np.loadtxt("../20220926/C5_rotation_02deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis9,data01_value9 = np.loadtxt("../20220926/TOP_02deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis10,data01_value10 = np.loadtxt("../20220926/Under_02deg_min_2mm_slit.DAT", comments=';', unpack=True, encoding="shift-jis")

#9/28
data01_axis11,data01_value11 = np.loadtxt("../20220928/B1_02deg_min_S1_1mm_S2_2mm.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis12,data01_value12 = np.loadtxt("../20220928/C1_02deg_min_S1_1mm_S2_2mm.DAT", comments=';', unpack=True, encoding="shift-jis")
data01_axis13,data01_value13 = np.loadtxt("../20220928/C1_02deg_min_S1_1mm_S2_2mm_grease_plus_05_5deg.DAT", comments=';', unpack=True, encoding="shift-jis")

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)
ax.set_xlim(0, 6)
#ax.set_ylim(1e-5, 1)
ax.set_xlabel("2θ")
ax.set_ylabel("R")
ax.set_yscale('log') 
ax.legend(loc="upper left")

data01_value1_max=max(data01_value1)
data01_value2_max=max(data01_value2)
data01_value3_max=max(data01_value3)
data01_value4_max=max(data01_value4)
data01_value5_max=max(data01_value5)
data01_value6_max=max(data01_value6)
data01_value7_max=max(data01_value7)
data01_value8_max=max(data01_value8)
data01_value9_max=max(data01_value9)
data01_value10_max=max(data01_value10)
data01_value11_max=max(data01_value11)
data01_value12_max=max(data01_value12)
data01_value13_max=max(data01_value13)

#error 
step=0.004
v_theta=0.2

data01_value1_E=np.sqrt(data01_value1*step/(v_theta/60))/(step/(v_theta/60))
data01_value2_E=np.sqrt(data01_value2*step/(v_theta/60))/(step/(v_theta/60))
data01_value3_E=np.sqrt(data01_value3*step/(v_theta/60))/(step/(v_theta/60))
data01_value4_E=np.sqrt(data01_value4*step/(v_theta/60))/(step/(v_theta/60))
data01_value5_E=np.sqrt(data01_value5*step/(v_theta/60))/(step/(v_theta/60))
data01_value6_E=np.sqrt(data01_value6*step/(v_theta/60))/(step/(v_theta/60))
data01_value7_E=np.sqrt(data01_value7*step/(v_theta/60))/(step/(v_theta/60))
data01_value8_E=np.sqrt(data01_value8*step/(v_theta/60))/(step/(v_theta/60))
data01_value9_E=np.sqrt(data01_value9*step/(v_theta/60))/(step/(v_theta/60))
data01_value10_E=np.sqrt(data01_value10*step/(v_theta/60))/(step/(v_theta/60))
data01_value11_E=np.sqrt(data01_value11*step/(v_theta/60))/(step/(v_theta/60))
data01_value12_E=np.sqrt(data01_value12*step/(v_theta/60))/(step/(v_theta/60))
data01_value13_E=np.sqrt(data01_value13*step/(v_theta/60))/(step/(v_theta/60))


# print(data01_value1_E)
data01_value1=data01_value1/data01_value1_max
data01_value2=data01_value2/data01_value2_max
data01_value3=data01_value3/data01_value3_max
data01_value4=data01_value4/data01_value4_max
data01_value5=data01_value5/data01_value5_max
data01_value6=data01_value6/data01_value6_max
data01_value7=data01_value7/data01_value7_max
data01_value8=data01_value8/data01_value8_max
data01_value9=data01_value9/data01_value9_max
data01_value10=data01_value10/data01_value10_max
data01_value11=data01_value11/data01_value11_max
data01_value12=data01_value12/data01_value12_max
data01_value13=data01_value13/data01_value13_max

#R_error
data01_value1_E=data01_value1_E/data01_value1_max
data01_value2_E=data01_value2_E/data01_value2_max
data01_value3_E=data01_value3_E/data01_value3_max
data01_value4_E=data01_value4_E/data01_value4_max
data01_value5_E=data01_value5_E/data01_value5_max
data01_value6_E=data01_value6_E/data01_value6_max
data01_value7_E=data01_value7_E/data01_value7_max
data01_value8_E=data01_value8_E/data01_value8_max
data01_value9_E=data01_value9_E/data01_value9_max
data01_value10_E=data01_value10_E/data01_value10_max
data01_value11_E=data01_value11_E/data01_value11_max
data01_value12_E=data01_value12_E/data01_value12_max
data01_value13_E=data01_value13_E/data01_value13_max



# plt.errorbar(data01_axis1, data01_value1, yerr=1, "", color="k", label="A2")
# plt.errorbar(data01_axis1, data01_value1, yerr=data01_value1_E)

# plt.plot(data01_axis1, data01_value1, "-", color="k", label="A2")
# plt.plot(data01_axis2, data01_value2, "-", color="r", label="A9")
# plt.plot(data01_axis3, data01_value3, "-", color="b", label="B3")
# plt.plot(data01_axis4, data01_value4, "-", color="g", label="B4")
plt.plot(data01_axis5, data01_value5, "-", color="m", label="C1")
plt.plot(data01_axis12, data01_value12, "-", color="y", label="C1_grease")
# plt.plot(data01_axis6, data01_value6, "-", color="c", label="C2")
# plt.plot(data01_axis7, data01_value7, "-", color="m", label="C4")
#plt.plot(data01_axis8, data01_value8, "-", color="#e41a1c", label="C5")
# plt.plot(data01_axis9, data01_value9, "-", color="#377eb8", label="TOP")
# plt.plot(data01_axis10, data01_value10, "-", color="#984ea3", label="Under")
# plt.plot(data01_axis11, data01_value11, "-", color="r", label="B1")

plt.plot(data01_axis13, data01_value13, "-", color="b", label="C1_grease_2mm_vertical_slit")

plt.legend(loc = "upper right")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#発散角見積もり
#0.5/x=0.025/(200-x)
#20(200-x)=x
#21x=4000

x=4000/21
print (x)

#tanθ=0.5/190.47619047619048
# Out:
# 190.47619047619048

# %%
def func_high (h):
    M=h*60.3+209.0602
    return M

def func_low (h):
    M=-h*60.3+209.0602
    return M

fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111)
ax.set_xlim(0, 3)
ax.set_xlabel("M (T)")
ax.set_ylabel("E (neV)")
ax.legend(loc="upper left")

x = np.linspace( 0, 3, 100)  
y1=func_high(x)
y2=func_low(x)

V_NiP=213.1994
V_drop=102.3082339
V_drop_05m=51.15411695
V1=V_NiP+V_drop
V2=V_NiP+V_drop_05m

plt.plot(x, y1, "-", color="m", label="high")
plt.plot(x, y2, "-", color="y", label="low")
plt.hlines(V1, 0, 3, color='g', linestyles='dotted', label="1m_droppd")
plt.hlines(V_drop, 0, 3, color='g', linestyles='dotted')
plt.hlines(V2, 0, 3, color='b', linestyles='dotted', label="0.5m_droppd")
plt.hlines(V_drop_05m, 0, 3, color='b', linestyles='dotted')
plt.legend(loc = "upper right")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from refnx.dataset import Data1D
data = Data1D(data=(x, data01_value1, data01_value1_E))

# %%
# %matplotlib inline

import numpy as np
np.random.seed(123)

# Choose the "true" parameters.
m_true = -0.9594
b_true = 4.294
f_true = 0.534

N = 50
x = np.sort(10 * np.random.rand(N))
yerr = 0.1 + 0.5*np.random.rand(N)
y = m_true*x + b_true
y += np.abs(f_true * y) * np.random.randn(N)
y += yerr * np.random.randn(N)

from refnx.analysis import Parameter, Model

def line(x, params, *args, **kwds):
    p_arr = np.array(params)
    return p_arr[0] + x * p_arr[1]

# the model needs parameters
p = Parameter(1, 'b', vary=True, bounds=(0, 10))
p |= Parameter(-2, 'm', vary=True, bounds=(-5, 0.5))

model = Model(p, fitfunc=line)

# ln(1 / 10)
# a value lying outside the limits is not possible
print(p[0].logp(1), p[0].logp(-1))

import scipy.stats as stats
# a normal distribution of mean 5 and standard deviation 1.
p[0].bounds = stats.norm(5, 1)

from refnx.analysis import Objective

lnf = Parameter(0, 'lnf', vary=True, bounds=(-10, 1))
objective = Objective(model, data, lnsigma=lnf)
print(objective.chisqr(), objective.logp(), objective.logl(), objective.logpost())

from refnx.analysis import CurveFitter

fitter = CurveFitter(objective)
fitter.fit('differential_evolution');

print(objective)
objective.plot();
# Out:
# -2.3025850929940455 -inf
# 2442940.623833105 -13.021581898241468 -1224612.6625893626 -1224625.6841712608
# 23it [00:00, 61.73it/s]
# ________________________________________________________________________________
# Objective - 140593126032288
# Dataset = <None>, 1451 points
# datapoints = 1451
# chi2 = 1502.8914767569772
# Weighted = True
# Transform = None
# ________________________________________________________________________________
# Parameters:      None
# <Parameter:     'lnf'     , value=-0.0535134 +/- 0.0265, bounds=[-10.0, 1.0]>
# ________________________________________________________________________________
# Parameters:      None
# ________________________________________________________________________________
# Parameters:      None
# <Parameter:      'b'      , value=2.42417 +/- 0.491, bounds=PDF(<scipy.stats._distn_infrastructure.rv_frozen object at 0x7fde635527c0>)>
# <Parameter:      'm'      , value=-0.51799 +/- 0.105, bounds=[-5.0, 0.5]>

# %%
from refnx.reflect import gui
gui()
# Out:
# Attribute Qt::AA_EnableHighDpiScaling must be set before QCoreApplication is created.
# 0

# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import scipy

import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.analysis import Transform, CurveFitter, Objective, Model, Parameter
from refnx.reflect import SLD, Slab, ReflectModel

# %%
print(f"refnx: {refnx.version.version}\n"
      f"scipy: {scipy.version.version}\n"
      f"numpy: {np.version.version}")
# Out:
# refnx: 0.1.30
# scipy: 1.7.3
# numpy: 1.21.5

# %%
pth = os.path.dirname(refnx.__file__)
DATASET_NAME = 'c_PLP0011859_q.txt'
file_path = os.path.join(pth, 'analysis', 'test', DATASET_NAME)

# %%
q = np.linspace(0.005, 0.3, 1001)
plt.plot(q, model(q))
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.yscale('log')

# %%
# first number is thickness, second number is roughness
# a native oxide layer
sio2_layer = sio2(30, 3)

# the film of interest
film_layer = film(250, 3)

# layer for the solvent
d2o_layer = d2o(0, 3)

si = SLD(2.07, name='Si')
sio2 = SLD(3.47, name='SiO2')
film = SLD(2.0, name='film')
d2o = SLD(6.36, name='d2o')

sio2_layer.thick.setp(bounds=(15, 50), vary=True)
sio2_layer.rough.setp(bounds=(1, 15), vary=True)

film_layer.thick.setp(bounds=(200, 300), vary=True)
film_layer.sld.real.setp(bounds=(0.1, 3), vary=True)
film_layer.rough.setp(bounds=(1, 15), vary=True)

d2o_layer.rough.setp(vary=True, bounds=(1, 15))
structure = si | sio2_layer | film_layer | d2o_layer
model = ReflectModel(structure, bkg=3e-6, dq=5.0)
model.scale.setp(bounds=(0.6, 1.2), vary=True)
model.bkg.setp(bounds=(1e-9, 9e-6), vary=True)
objective = Objective(model, data, transform=Transform('logY'))
print(objective.chisqr(), objective.logp(), objective.logl(), objective.logpost())
fitter = CurveFitter(objective)
fitter.fit('differential_evolution');
objective.plot()
plt.legend()
plt.xlabel('Q')
plt.ylabel('logR')
plt.legend();
# Out:
# 34376.69092305155 -5.013178251637257 -16157.428065740693 -16162.441243992329
# 42it [00:07,  5.51it/s]

# %%
print(objective)
# Out:
# ________________________________________________________________________________
# Objective - 140593146919328
# Dataset = c_PLP0011859_q
# datapoints = 408
# chi2 = 921.6897811715162
# Weighted = True
# Transform = Transform('logY')
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.879254 +/- 0.00304, bounds=[0.6, 1.2]>
# <Parameter:     'bkg'     , value=4.53986e-07 +/- 2.15e-08, bounds=[1e-09, 9e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'q_offset'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - '
# ________________________________________________________________________________
# Parameters:      'Si'
# ...
